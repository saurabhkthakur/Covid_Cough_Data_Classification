# %%
import os
import pandas

# %%
os.lis()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
/content/drive/MyDrive/dd/public_dataset

# %%
os.listdir('/content/drive/MyDrive/dd/public_dataset')

# %%
import glob
  
  

files = glob.glob('/content/drive/MyDrive/dd/public_dataset/*.json')

# %%
len(files)
# Out:
# 20072

# %%
import pandas as pd

pd.read_json('/content/drive/MyDrive/dd/public_dataset/9d2b1593-a662-410a-9eef-5d69793c11ee.json', typ='series')
# Out:
# datetime          2020-05-01T03:04:37.198069+00:00
# cough_detected                              0.9937
# dtype: object

# %%
files[0]
# Out:
# '/content/drive/MyDrive/dd/public_dataset/9d2b1593-a662-410a-9eef-5d69793c11ee.json'

# %%
import json
with open('/content/drive/MyDrive/dd/public_dataset/9d2b1593-a662-410a-9eef-5d69793c11ee.json', 'r') as f:
    data = json.load(f)
    print(data)
# Out:
# {'datetime': '2020-05-01T03:04:37.198069+00:00', 'cough_detected': '0.9937'}

# %%
df = pd.DataFrame(data, index=[0])

# %%
df
# Out:
#                            datetime cough_detected
# 0  2020-05-01T03:04:37.198069+00:00         0.9937

# %%
from tqdm import tqdm_notebook as tq

# %%
covid_19 =[]
healthy = []
symp=[]
stat=[]

for file in tq(files):

  with open(file, 'r') as f:
      data = json.load(f)
      try:
        if data['status'] == 'COVID-19':
          data['file_name']= file
          covid_19.append(data)

        elif data['status'] == 'healthy':
          data['file_name']= file
          healthy.append(data)

        elif data['status'] == 'symptomatic':
          data['file_name']= file
          symp.append(data)

        
        
        print(data['status'])
        
      except:
        data['file_name']= file
        stat.append(data)
        print('Status is not available')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# Streaming output truncated to the last 5000 lines.
# Status is not available
# healthy
# healthy
# Status is not available
# healthy
# Status is not available
# COVID-19
# Status is not available
# Status is not available
# healthy
# Status is not available
# healthy
# Status is not available
# healthy
# COVID-19
# healthy
# Status is not available
# healthy
# Status is not available
# Status is not available
# symptomatic
# Status is not available
# healthy
# Status is not available
# healthy
# COVID-19
# healthy
# Status is not available
# Status is not available
# healthy
# healthy
# healthy
# healthy
# healthy
# healthy
# Status is not available
# Status is not available
# healthy
# Status is not available
# healthy
# healthy
# healthy
# Status is not available
# ...

# %%
pd.DataFrame.from_records([data])
# Out:
#                            datetime cough_detected  ... fever_muscle_pain   status
# 0  2020-04-13T21:30:59.801831+00:00         0.9609  ...             False  healthy
#
# [1 rows x 9 columns]

# %%
with open(files[4], 'r') as f:
    data = json.load(f)
    try:
      print(data)
      print(data['status'])
      
    except:
      print('Status is not available')
# Out:
# {'datetime': '2020-05-11T13:23:11.745799+00:00', 'cough_detected': '0.9259', 'latitude': '-53.1', 'longitude': '-70.9', 'age': '30', 'gender': 'female', 'respiratory_condition': 'False', 'fever_muscle_pain': 'True', 'status': 'COVID-19'}
# COVID-19

# %%
pd.DataFrame(healthy).to_csv('/content/drive/MyDrive/dd/healthy.csv',index=False)

# %%
pd.DataFrame(covid_19).to_csv('/content/drive/MyDrive/dd/covid.csv',index=False)

# %%
pd.DataFrame(symp).to_csv('/content/drive/MyDrive/dd/sympt.csv',index=False)

# %%
pd.DataFrame(stat).to_csv('/content/drive/MyDrive/dd/status_NA.csv',index=False)

# %%
import pandas as pd
health_meta = pd.read_csv('/content/drive/MyDrive/dd/healthy.csv')
covid_19_meta = pd.read_csv('/content/drive/MyDrive/dd/covid.csv')
symp_meta = pd.read_csv('/content/drive/MyDrive/dd/sympt.csv')

# %%
print(health_meta.shape,covid_19_meta.shape,symp_meta.shape)
# Out:
# (8562, 13) (1010, 13) (1742, 13)

# %%
health_meta['class_label']=0
covid_19_meta['class_label']=1
symp_meta['class_label']=2

# %%
main_df = pd.concat([health_meta,covid_19_meta,symp_meta])

# %%
main_df
# Out:
#                               datetime  ...  class_label
# 0     2020-04-15T07:00:56.575141+00:00  ...            0
# 1     2020-04-20T13:53:16.793373+00:00  ...            0
# 2     2020-04-14T02:22:51.274537+00:00  ...            0
# 3     2020-04-14T04:06:31.661418+00:00  ...            0
# 4     2020-05-16T23:23:55.357099+00:00  ...            0
# ...                                ...  ...          ...
# 1737  2020-04-22T07:52:24.516106+00:00  ...            2
# 1738  2020-09-03T01:42:21.934676+00:00  ...            2
# 1739  2020-04-19T19:41:00.160504+00:00  ...            2
# 1740  2020-04-14T23:28:05.849739+00:00  ...            2
# 1741  2020-07-09T15:31:49.399819+00:00  ...            2
#
# [11314 rows x 14 columns]

# %%
main_df[main_df['status']=='symptomatic']
# Out:
#                                datetime  ...  class_label
# 9110   2020-05-20T04:50:53.025283+00:00  ...            1
# 9111   2020-07-04T23:13:21.664242+00:00  ...            1
# 9112   2020-04-13T15:28:08.706801+00:00  ...            1
# 9113   2020-09-06T21:39:03.910925+00:00  ...            1
# 9114   2020-04-14T16:00:52.684124+00:00  ...            1
# ...                                 ...  ...          ...
# 10741  2020-04-24T13:23:57.878040+00:00  ...            1
# 10742  2020-04-22T07:52:24.516106+00:00  ...            1
# 10743  2020-09-03T01:42:21.934676+00:00  ...            1
# 10744  2020-04-19T19:41:00.160504+00:00  ...            1
# 10745  2020-07-09T15:31:49.399819+00:00  ...            1
#
# [1636 rows x 14 columns]

# %%
main_df['class_label']=main_df['class_label'].apply(lambda x: 1 if x == 2 else x)

# %%
import warnings
warnings.filterwarnings("ignore")
features = []
labels = []
frames_max = 0
counter = 0
total_samples = len(main_df)
n_mfcc = 14

for index, row in tq(main_df.iterrows()):

  try:

  
    file_path = str(row["file_name"]).split('.')[0]+'.webm'
    class_label = row['class_label']

    # Extract MFCCs (do not add padding)
    mfccs = get_mfcc(file_path, 0, n_mfcc)
    
    # Save current frame count
    num_frames = mfccs.shape[1]
    
    # Add row (feature / label)
    features.append(mfccs)
    labels.append(class_label)

    # Update frames maximum
    if (num_frames > frames_max):
        frames_max = num_frames

    # Notify update every N files
    if (counter == 500):
        print("Status: {}/{}".format(index+1, total_samples))
        counter = 0

    counter += 1
  except:
    print('error occored in file', row['file_name'])    
print("Finished: {}/{}".format(index, total_samples))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
# Add padding to features with less than frames than frames_max
padded_features = add_padding(features, frames_max)

# %%
# Verify shapes
print("Raw features length: {}".format(len(features)))
print("Padded features length: {}".format(len(padded_features)))
print("Feature labels length: {}".format(len(labels)))
# Out:
# Raw features length: 10654
# Padded features length: 10654
# Feature labels length: 10654

# %%
# Convert features (X) and labels (y) to Numpy arrays
X = np.array(padded_features)
y = np.array(labels)

# Optionally save the features to disk
np.save("/content/drive/MyDrive/dd/Xb-mfcc", X)
np.save("/content/drive/MyDrive/dd/yb-mfcc", y)

# %%
len(np.nonzero(y)[0])
# Out:
# 2473

# %%
len(np.where(y== 0)[0])
# Out:
# 8181

# %%
main_df['class_label'].value_counts()
# Out:
# 0    8181
# 1    2565
# Name: class_label, dtype: int64

# %%
main_df.iloc[np.nonzero(y)[0]]
# Out:
#                                datetime  ...  class_label
# 8181   2020-05-11T13:23:11.745799+00:00  ...            1
# 8182   2020-04-10T14:00:26.747919+00:00  ...            1
# 8183   2020-04-10T02:09:50.627946+00:00  ...            1
# 8184   2020-04-14T10:43:40.337088+00:00  ...            1
# 8185   2020-04-14T05:02:16.784433+00:00  ...            1
# ...                                 ...  ...          ...
# 10649  2020-05-04T16:50:01.432250+00:00  ...            1
# 10650  2020-08-20T23:41:00.916458+00:00  ...            1
# 10651  2020-05-12T20:29:31.904489+00:00  ...            1
# 10652  2020-04-14T00:18:44.621490+00:00  ...            1
# 10653  2020-07-20T23:11:30.881571+00:00  ...            1
#
# [2473 rows x 14 columns]

# %%
X[0][np.where(X[0]!=0)]
# Out:
# array([-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, ...,
#        -1.7745733e-04, -2.6114180e-04, -2.7622617e-04], dtype=float32)
